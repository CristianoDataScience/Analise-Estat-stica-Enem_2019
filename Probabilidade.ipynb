# %% [markdown]
# <a href="https://colab.research.google.com/github/CristianoDataScience/Analise-Estat-stica-Enem_2019/blob/main/Probabilidade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Prababilidade

# %%
import numpy as np
import pandas as pd

# %%
enem_sp = pd.read_csv('/content/drive/MyDrive/curso estatistica/enem_2019_tratado.csv',
                      sep=',', encoding='iso-8859-1')
enem_sp.head()
# Out:
#   NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  IDADE SEXO  TP_ESTADO_CIVIL    RACA  \
# 0     1,90E+11            Santa Isabel     22    M                1   parda
# 1     1,90E+11               São Paulo     17    F                1   parda
# 2     1,90E+11   São Bernardo do Campo     19    M                1   parda
# 3     1,90E+11              Embu-Guaçu     17    F                1   parda
# 4     1,90E+11               Guarulhos     23    F                1  branca
#
#    TP_NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  ... NOTA_MT  \
# 0                 1                1  nao_respondeu         NaN  ...   600.2
# 1                 1                2        privada  15567761.0  ...   731.8
# 2                 1                2        publica  35904958.0  ...   393.2
# 3                 1                2        publica         NaN  ...   419.2
# 4                 1                1  nao_respondeu         NaN  ...   796.1
#
#    TP_LINGUA  TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  COMP5  \
# 0     Ingles                1.0  160.0  200.0  180.0  200.0  200.0
# 1     Ingles                1.0  160.0  120.0  200.0  200.0  200.0
# 2   Espanhol                1.0   80.0  160.0  120.0  100.0  100.0
# 3     Ingles                1.0  120.0  120.0  120.0  120.0   80.0
# 4     Ingles                1.0  160.0  200.0  180.0  180.0  160.0
#
#    NOTA_REDACAO INTERNET
# 0         940.0      Sim
# 1         880.0      Nao
# 2         560.0      Sim
# 3         560.0      Sim
# 4         880.0      Sim
#
# [5 rows x 28 columns]

# %%
enem_guarulhos = enem_sp.loc[enem_sp.NO_MUNICIPIO_RESIDENCIA == 'Guarulhos']
enem_guarulhos.head()
# Out:
#     NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  IDADE SEXO  TP_ESTADO_CIVIL  \
# 4       1,90E+11               Guarulhos     23    F                1
# 56      1,90E+11               Guarulhos     17    F                1
# 69      1,90E+11               Guarulhos     27    M                1
# 130     1,90E+11               Guarulhos     28    F                1
# 202     1,90E+11               Guarulhos     17    F                1
#
#               RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA  \
# 4           branca                 1                1  nao_respondeu
# 56           parda                 1                2        publica
# 69   nao_declarado                 1                1  nao_respondeu
# 130         branca                 1                1  nao_respondeu
# 202          parda                 1                2        publica
#
#       CO_ESCOLA  ... NOTA_MT  TP_LINGUA  TP_STATUS_REDACAO  COMP1  COMP2  \
# 4           NaN  ...   796.1     Ingles                1.0  160.0  200.0
# 56          NaN  ...   468.1   Espanhol                1.0  100.0   60.0
# 69          NaN  ...   743.8     Ingles                1.0  120.0  180.0
# 130         NaN  ...   415.1     Ingles                1.0  160.0  120.0
# 202  35005824.0  ...   594.9     Ingles                1.0  120.0  120.0
#
#      COMP3  COMP4  COMP5  NOTA_REDACAO INTERNET
# 4    180.0  180.0  160.0         880.0      Sim
# 56    60.0  100.0    0.0         320.0      Sim
# 69   120.0  120.0  160.0         700.0      Sim
# 130  160.0  120.0  100.0         660.0      Sim
# 202  120.0  120.0  160.0         640.0      Sim
#
# [5 rows x 28 columns]

# %%
enem_bauru = enem_sp.loc[enem_sp.NO_MUNICIPIO_RESIDENCIA == 'Bauru']
enem_bauru.head()
# Out:
#      NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  IDADE SEXO  TP_ESTADO_CIVIL  \
# 477      1,90E+11                   Bauru     21    M                1
# 928      1,90E+11                   Bauru     17    M                1
# 1070     1,90E+11                   Bauru     19    M                1
# 1235     1,90E+11                   Bauru     18    F                1
# 1506     1,90E+11                   Bauru     19    M                1
#
#          RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  \
# 477    branca                 1                1  nao_respondeu         NaN
# 928   amarela                 1                2        publica  35025240.0
# 1070   branca                 1                1  nao_respondeu         NaN
# 1235    parda                 1                2        privada  35115435.0
# 1506   branca                 1                1  nao_respondeu         NaN
#
#       ... NOTA_MT  TP_LINGUA  TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  \
# 477   ...   664.1     Ingles                1.0  100.0  120.0  120.0  120.0
# 928   ...   740.3     Ingles                1.0  140.0  120.0  120.0  140.0
# 1070  ...   789.2     Ingles                1.0  160.0  200.0  200.0  200.0
# 1235  ...    71.5     Ingles                1.0  140.0  140.0  140.0  140.0
# 1506  ...   533.8   Espanhol                1.0  120.0  140.0  120.0  100.0
#
#       COMP5  NOTA_REDACAO INTERNET
# 477   100.0         560.0      Sim
# 928   100.0         620.0      Sim
# 1070  200.0         960.0      Sim
# 1235  120.0         680.0      Sim
# 1506  140.0         620.0      Sim
#
# [5 rows x 28 columns]

# %%
len(enem_guarulhos)
# Out:
# 15647

# %%
len(enem_bauru)
# Out:
# 4171

# %%
# Criando Probabilidade
def probab(A, E):
  resultado = (A / E)*100
  print('{:.2f}%'.format(resultado))

# %%
# Probabilidade de retirar um vestibulando de Guarulhos
probab(len(enem_guarulhos), len(enem_sp))
# Out:
# 3.13%

# %%
# Probabilidade de retirar um vestibulando de Bauru
probab(len(enem_bauru), len(enem_sp))
# Out:
# 0.83%

# %% [markdown]
# ## Probabilidade de não ocorrer um evento

# %%
# Criando uma função probabilidade de não ocorrer um evento
def probab_nao(A, E):
  resultado = (1- (A / E))*100
  print('{:.2f}%'.format(resultado))

# %%
# Probabilidade de não retirar um vestibulando de guarulhos
probab_nao(len(enem_guarulhos), len(enem_sp))
# Out:
# 96.87%

# %%
# Probabilidade de não retirar um vestibulando de guarulhos e nem de Bauru
probab_nao(len(enem_guarulhos) + len(enem_bauru), len(enem_sp))
# Out:
# 96.04%

# %% [markdown]
# ## Probabilidade da união mutuamente exclusivos (AUB)

# %%
# Criando função probabilidade da união mutuamente exclusivos (AUB)
def probab_uniao(A, B, E):
  resultado = (A/E + B/E)*100
  print('{:.2f}%'.format(resultado))

# %%
# Probabilidade de retirar um vestibulando de Guarulhos ou de Bauru
probab_uniao(len(enem_guarulhos), len(enem_bauru), len(enem_sp))
# Out:
# 3.96%

# %% [markdown]
# ## Probabilidade da intersecção de dois eventos

# %%
# Criando função probabilidade da intersecção de dois eventos
def probab_inter(A, B, E):
  resultado = (A/E * B/E)*100
  print('{:.3f}%'.format(resultado))

# %%
# Probabilidade de retirar um vestibulando de Guarulhos e de Bauru (com reposição)
probab_inter(len(enem_guarulhos), len(enem_bauru), len(enem_sp))
# Out:
# 0.026%

# %% [markdown]
# ## Probabilidade Condicional

# %%
# Criando função probabilidade condicional
def probab_cond(AB, B):
  resultado = (AB / B)*100
  print('{:.2f}%'.format(resultado))

# %%
# Probabilidade de retirar uma mulher parda
mulher = enem_sp.loc[enem_sp.SEXO == 'F']
mulher
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  IDADE SEXO  TP_ESTADO_CIVIL  \
# 1          1,90E+11               São Paulo     17    F                1
# 3          1,90E+11              Embu-Guaçu     17    F                1
# 4          1,90E+11               Guarulhos     23    F                1
# 5          1,90E+11   São José do Rio Preto     18    F                1
# 7          1,90E+11             Santo André     20    F                1
# ...             ...                     ...    ...  ...              ...
# 499934     1,90E+11               São Paulo     20    F                1
# 499935     1,90E+11               São Paulo     18    F                1
# 499936     1,90E+11               São Paulo     17    F                1
# 499937     1,90E+11               São Paulo     17    F                1
# 499939     1,90E+11                  Araras     18    F                1
#
#           RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  \
# 1        parda                 1                2        privada  15567761.0
# 3        parda                 1                2        publica         NaN
# 4       branca                 1                1  nao_respondeu         NaN
# 5       branca                 1                2        publica  35028927.0
# 7        parda                 1                1  nao_respondeu         NaN
# ...        ...               ...              ...            ...         ...
# 499934   parda                 1                1  nao_respondeu         NaN
# 499935   parda                 1                1  nao_respondeu         NaN
# 499936   preta                 1                2        publica  35925457.0
# 499937   parda                 1                2        publica  35001156.0
# 499939  branca                 1                2        publica  35019926.0
#
#         ... NOTA_MT  TP_LINGUA  TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  \
# 1       ...   731.8     Ingles                1.0  160.0  120.0  200.0  200.0
# 3       ...   419.2     Ingles                1.0  120.0  120.0  120.0  120.0
# 4       ...   796.1     Ingles                1.0  160.0  200.0  180.0  180.0
# 5       ...   612.8   Espanhol                1.0  120.0  160.0  120.0   80.0
# 7       ...   508.5   Espanhol                1.0  120.0  120.0  120.0  100.0
# ...     ...     ...        ...                ...    ...    ...    ...    ...
# 499934  ...   514.8   Espanhol                1.0  100.0  120.0  120.0  140.0
# 499935  ...   479.1   Espanhol                1.0  100.0  120.0  120.0  140.0
# 499936  ...    43.2   Espanhol                1.0   80.0  120.0  140.0  120.0
# 499937  ...   487.3     Ingles                1.0  120.0   80.0   60.0  120.0
# 499939  ...   559.5     Ingles                1.0  120.0  120.0  120.0  120.0
#
#         COMP5  NOTA_REDACAO INTERNET
# 1       200.0         880.0      Nao
# 3        80.0         560.0      Sim
# 4       160.0         880.0      Sim
# 5       100.0         580.0      Nao
# 7        80.0         540.0      Sim
# ...       ...           ...      ...
# 499934  140.0         620.0      Sim
# 499935  100.0         580.0      Sim
# 499936  100.0         560.0      Sim
# 499937    0.0         380.0      Sim
# 499939  140.0         620.0      Sim
#
# [290122 rows x 28 columns]

# %%
mulher_parda = mulher.loc[mulher.RACA == 'parda']
mulher_parda
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  IDADE SEXO  TP_ESTADO_CIVIL  \
# 1          1,90E+11               São Paulo     17    F                1
# 3          1,90E+11              Embu-Guaçu     17    F                1
# 7          1,90E+11             Santo André     20    F                1
# 9          1,90E+11             Santo André     44    F                2
# 11         1,90E+11                   Guará     17    F                1
# ...             ...                     ...    ...  ...              ...
# 499932     1,90E+11   Santa Bárbara d'Oeste     18    F                1
# 499933     1,90E+11                Pardinho     17    F                0
# 499934     1,90E+11               São Paulo     20    F                1
# 499935     1,90E+11               São Paulo     18    F                1
# 499937     1,90E+11               São Paulo     17    F                1
#
#          RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  \
# 1       parda                 1                2        privada  15567761.0
# 3       parda                 1                2        publica         NaN
# 7       parda                 1                1  nao_respondeu         NaN
# 9       parda                 1                1  nao_respondeu         NaN
# 11      parda                 1                2        publica  35023310.0
# ...       ...               ...              ...            ...         ...
# 499932  parda                 1                1  nao_respondeu         NaN
# 499933  parda                 1                2        publica         NaN
# 499934  parda                 1                1  nao_respondeu         NaN
# 499935  parda                 1                1  nao_respondeu         NaN
# 499937  parda                 1                2        publica  35001156.0
#
#         ... NOTA_MT  TP_LINGUA  TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  \
# 1       ...   731.8     Ingles                1.0  160.0  120.0  200.0  200.0
# 3       ...   419.2     Ingles                1.0  120.0  120.0  120.0  120.0
# 7       ...   508.5   Espanhol                1.0  120.0  120.0  120.0  100.0
# 9       ...   488.1   Espanhol                1.0  120.0  120.0  120.0  120.0
# 11      ...   535.1     Ingles                1.0  140.0  120.0  140.0  160.0
# ...     ...     ...        ...                ...    ...    ...    ...    ...
# 499932  ...    52.1     Ingles                1.0  140.0  120.0  180.0  160.0
# 499933  ...   534.7     Ingles                1.0  140.0  120.0  120.0  120.0
# 499934  ...   514.8   Espanhol                1.0  100.0  120.0  120.0  140.0
# 499935  ...   479.1   Espanhol                1.0  100.0  120.0  120.0  140.0
# 499937  ...   487.3     Ingles                1.0  120.0   80.0   60.0  120.0
#
#         COMP5  NOTA_REDACAO INTERNET
# 1       200.0         880.0      Nao
# 3        80.0         560.0      Sim
# 7        80.0         540.0      Sim
# 9        40.0         520.0      Sim
# 11      120.0         680.0      Sim
# ...       ...           ...      ...
# 499932  180.0         780.0      Nao
# 499933  160.0         660.0      Sim
# 499934  140.0         620.0      Sim
# 499935  100.0         580.0      Sim
# 499937    0.0         380.0      Sim
#
# [89254 rows x 28 columns]

# %%
probab_cond(len(mulher_parda), len(mulher))
# Out:
# 30.76%
